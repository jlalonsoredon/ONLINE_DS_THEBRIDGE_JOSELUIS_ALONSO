# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![ejercicios.png](attachment:ejercicios.png)

# %% [markdown]
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomesticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas ultimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
# * Método que calcula la media de ventas de los ultimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class Tienda:
  tipo = "Electrodomésticos"
  abierta = True
#funcion constructor
  def __init__(self, nombre, direccion, num_empleados, ventas_3m):
      self.nombre = nombre
      self.direccion = direccion
      self.num_empleados = num_empleados
      self.ventas_3m = ventas_3m

#Devuelve la suma total de las ventas de los 3 meses
  def total_ventas(self):
      return sum(self.ventas_3m)

#Calcula la media de ventas totales por cada empleado.
  def media_ventas_empleado(self):
      total = self.total_ventas()
      if self.num_empleados == 0:
          return 0
      return total / self.num_empleados

#Imprime la dirección
  def obtener_identidad(self):
      print ("Tienda:", self.nombre, "  Dirección:", self.direccion)

#devuelve la facturación del último mes
  def ventas_ultimo_mes(self):
      return self.ventas_3m[-1]

  def proyeccion_marketing(self, inversion):
      if inversion < 1000:
        factor = 1.2
      else:
        factor = 1.5
      for i in range(len(self.ventas_3m)):
        self.ventas_3m[i] = int(self.ventas_3m[i] * factor)

      return self.ventas_3m


t1 = Tienda("ElectroHogar", "Gran via 1", 5, [12000, 15000, 13500])
t2 = Tienda("ElectroHogar2", "Tabira 2", 8, [20000, 22000, 25000])
t3 = Tienda("ElectroHogar3", "Avenida 3", 4, [9000, 8500, 11000])

lista_tiendas = [t1, t2, t3]

print("--- Comprobando {t1.nombre} ---")
print("Atributos comunes: Tipo: {t1.tipo}, Abierta: {t1.abierta}")
t1.obtener_identidad()
print("Ventas totales:", t1.total_ventas(),"€")
print("Media por empleado:", t1.media_ventas_empleado(), "€")
print("Ventas último mes (antes marketing):", t1.ventas_ultimo_mes(), "€")

print("--- Ventas del último mes (todas) ---")
total_glogal = 0
for t in lista_tiendas:
  total_glogal = t.total_ventas() + total_glogal
print("Total de ventas en todas las tiendas:", total_glogal, "€")

for t in lista_tiendas:
    if "Avenida" in t.direccion:
        print("Encontrada:", t.nombre, " Dirección completa", t.direccion)
# Out:
# --- Comprobando {t1.nombre} ---
# Atributos comunes: Tipo: {t1.tipo}, Abierta: {t1.abierta}
# Tienda: ElectroHogar  | Dirección: Gran via 1
# Ventas totales: 40500 €
# Media por empleado: 8100.0 €
# Ventas último mes (antes marketing): 13500 €
# --- Ventas del último mes (todas) ---
# Total de ventas en todas las tiendas: 136000 €
# Encontrada: ElectroHogar3  Dirección completa Avenida 3

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
class Perro:
    # Atributos comunes a todos los perros
    patas = 4
    orejas = 2
    ojos = 2

    def __init__(self, raza, pelo="Marrón", dueño=None):
        self.raza = raza
        self.pelo = pelo
        self.dueño = dueño
        self.velocidad = 0

#Suma el valor recibido a la velocidad actual del perro
    def andar(self, aumento_velocidad):
        self.velocidad += aumento_velocidad
        print(f"El perro ha empezado a andar. Velocidad actual: {self.velocidad}")

#para parar se actuliza la velcidad a 0
    def parar(self):
        self.velocidad = 0
        print("El perro se ha parado. Velocidad: 0")

#concatena el mensaje con Guau
    def ladrar(self, mensaje):
        return "GUAU! " + str(mensaje)


# Crear un objeto de tipo Perro sin dueño
mi_perro = Perro(raza="Golden Retriever")

# Comprobación de atributos
print("--- Atributos del Perro ---")
print("Raza:", mi_perro.raza)
print("Color de pelo:", mi_perro.pelo)
print("¿Tiene dueño?:", mi_perro.dueño)
print("Patas:", mi_perro.patas, "| Orejas:", mi_perro.orejas, "| Ojos:", mi_perro.ojos)
print("Velocidad inicial:", mi_perro.velocidad)

print("\n--- Pruebas de Métodos ---")

# Probar que ande y comprobar velocidad
mi_perro.andar(5)
print("Velocidad tras andar:", mi_perro.velocidad)

# Probar el método ladrar
print("Mensaje del perro:", mi_perro.ladrar("¡Quiero jugar!"))

# Parar al perro
mi_perro.parar()
print("Velocidad final:", mi_perro.velocidad)
# Out:
# --- Atributos del Perro ---
# Raza: Golden Retriever
# Color de pelo: Marrón
# ¿Tiene dueño?: None
# Patas: 4 | Orejas: 2 | Ojos: 2
# Velocidad inicial: 0
#
# --- Pruebas de Métodos ---
# El perro ha empezado a andar. Velocidad actual: 5
# Velocidad tras andar: 5
# Mensaje del perro: GUAU! ¡Quiero jugar!
# El perro se ha parado. Velocidad: 0
# Velocidad final: 0
